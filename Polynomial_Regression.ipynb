# %% [markdown]
# <a href="https://colab.research.google.com/github/audreychela/Audrey_first_repo/blob/main/Polynomial_Regression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#import libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures

# %% [markdown]
# ## Polymonial

# %%
#create simple dataset
x = np.array([0,2,3,4])
y = np.array([1,3,7,13])

# %%
#plot lineplot or regression plot
sns.regplot(x=x, y=y);

# %%
# for the data to be accepted in ml, it has to be in 2D
x = np.array([0,2,3,4]).reshape(-1,1) # 1 is the number of columns and -1 is flexible way of arranging values.
y = np.array([1,3,7,13])
x
# Out:
# array([[0],
#        [2],
#        [3],
#        [4]])

# %%
#check polymonial documentation
# ?PolynomialFeatures

# %%
#2 degree polymonial
poly = PolynomialFeatures(degree=2)
x_poly = poly.fit_transform(x)
x_poly
# Out:
# array([[ 1.,  0.,  0.],
#        [ 1.,  2.,  4.],
#        [ 1.,  3.,  9.],
#        [ 1.,  4., 16.]])

# %%
#create a model
lr = LinearRegression()
lr.fit(x, y)
# Out:
# LinearRegression()

# %%
#check the score
lr.score(x,y)
# Out:
# 0.8503401360544218

# %%
#model prediction
y_pred1 =lr.predict(x)
y_pred1
# Out:
# array([-0.42857143,  5.28571429,  8.14285714, 11.        ])

# %%
#get resideual and check for homoscedaciticity
resd = y - y_pred
resd
# Out:
# array([-182., -180., -176., -170.])

# %%
# this is how to plot residual against predicted. on big data it will make sense
plt.scatter(y_pred1, resd,edgecolors="k", color="skyblue");

# %%
#create model
lr1 = LinearRegression()
lr1.fit(x_poly, y)
# Out:
# LinearRegression()

# %%
lr1.score(x_poly,y)
# Out:
# 1.0

# %%
y
# Out:
# array([ 1,  3,  7, 13])

# %%
y_pred = lr1.predict(x_poly)
y_pred
# Out:
# array([ 1.,  3.,  7., 13.])

# %%
#create new unseen data
new_value =np.array([14]).reshape(-1,1)
poly = PolynomialFeatures(degree=2)
new_poly = poly.fit_transform(new_value)
new_poly
# Out:
# array([[  1.,  14., 196.]])

# %%
#predict
y_pred = lr1.predict(new_poly)
y_pred
# Out:
# array([183.])
